# %% [markdown]
# # Module: Pandas Assignments
# ## Lesson: Pandas
# ### Assignment 1: DataFrame Creation and Indexing
#
# 1. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Set the index to be the first column.
# 2. Create a Pandas DataFrame with columns 'A', 'B', 'C' and index 'X', 'Y', 'Z'. Fill the DataFrame with random integers and access the element at row 'Y' and column 'B'.
#
# ### Assignment 2: DataFrame Operations
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Add a new column that is the product of the first two columns.
# 2. Create a Pandas DataFrame with 3 columns and 4 rows filled with random integers. Compute the row-wise and column-wise sum.
#
# ### Assignment 3: Data Cleaning
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Introduce some NaN values. Fill the NaN values with the mean of the respective columns.
# 2. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Introduce some NaN values. Drop the rows with any NaN values.
#
# ### Assignment 4: Data Aggregation
#
# 1. Create a Pandas DataFrame with 2 columns: 'Category' and 'Value'. Fill the 'Category' column with random categories ('A', 'B', 'C') and the 'Value' column with random integers. Group the DataFrame by 'Category' and compute the sum and mean of 'Value' for each category.
# 2. Create a Pandas DataFrame with 3 columns: 'Product', 'Category', and 'Sales'. Fill the DataFrame with random data. Group the DataFrame by 'Category' and compute the total sales for each category.
#
# ### Assignment 5: Merging DataFrames
#
# 1. Create two Pandas DataFrames with a common column. Merge the DataFrames using the common column.
# 2. Create two Pandas DataFrames with different columns. Concatenate the DataFrames along the rows and along the columns.
#
# ### Assignment 6: Time Series Analysis
#
# 1. Create a Pandas DataFrame with a datetime index and one column filled with random integers. Resample the DataFrame to compute the monthly mean of the values.
# 2. Create a Pandas DataFrame with a datetime index ranging from '2021-01-01' to '2021-12-31' and one column filled with random integers. Compute the rolling mean with a window of 7 days.
#
# ### Assignment 7: MultiIndex DataFrame
#
# 1. Create a Pandas DataFrame with a MultiIndex (hierarchical index). Perform some basic indexing and slicing operations on the MultiIndex DataFrame.
# 2. Create a Pandas DataFrame with MultiIndex consisting of 'Category' and 'SubCategory'. Fill the DataFrame with random data and compute the sum of values for each 'Category' and 'SubCategory'.
#
# ### Assignment 8: Pivot Tables
#
# 1. Create a Pandas DataFrame with columns 'Date', 'Category', and 'Value'. Create a pivot table to compute the sum of 'Value' for each 'Category' by 'Date'.
# 2. Create a Pandas DataFrame with columns 'Year', 'Quarter', and 'Revenue'. Create a pivot table to compute the mean 'Revenue' for each 'Quarter' by 'Year'.
#
# ### Assignment 9: Applying Functions
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Apply a function that doubles the values of the DataFrame.
# 2. Create a Pandas DataFrame with 3 columns and 6 rows filled with random integers. Apply a lambda function to create a new column that is the sum of the existing columns.
#
# ### Assignment 10: Working with Text Data
#
# 1. Create a Pandas Series with 5 random text strings. Convert all the strings to uppercase.
# 2. Create a Pandas Series with 5 random text strings. Extract the first three characters of each string.

# %%
import pandas as pd
import numpy as np
#Assignment 1.1

df = pd.DataFrame(np.random.randint(1 , 11 , size = (6 ,4)) , columns= [ 'A' , 'B' , 'C' , 'D'])
df.set_index('A')
# Out:
#    B   C  D
# A
# 6  8  10  3
# 6  6   1  2
# 1  6   3  8
# 3  8   3  5
# 8  9   5  8
# 2  8   5  8

# %%
#Assignment 1.2
df = pd.DataFrame(np.random.randint ( 1 , 11 , size = (3,3)) , index=['X' , 'Y' , 'Z' ] , columns=['A' , 'B' , 'C'])
df
# Out:
#    A  B  C
# X  3  3  4
# Y  2  6  6
# Z  3  4  8

# %%
#Assignment 2.1
df = pd.DataFrame(np.random.randint(1, 11 , size = (5,3)))
df[3] = df[0] * df[1]
df
# Out:
#     0  1  2   3
# 0   2  6  2  12
# 1   7  8  5  56
# 2  10  4  9  40
# 3   4  2  9   8
# 4   8  5  7  40

# %%
#Assignment 2.2
df = pd.DataFrame(np.random.randint(1, 11 , size = (4,3)))
print(df)
print("-----")
print(f"row sum = \n {df.sum(axis=1)}")
print(f"column sum = \n {df.sum(axis=0)}")
# Out:
#    0  1   2
# 0  6  7   3
# 1  6  3   6
# 2  6  1  10
# 3  5  4   5
# -----
# row sum =
#  0    16
# 1    15
# 2    17
# 3    14
# dtype: int64
# column sum =
#  0    23
# 1    15
# 2    24
# dtype: int64

# %%
#Assignment 3.1
df = pd.DataFrame(np.random.randint(1, 100, size=(5, 3)), columns=['A', 'B', 'C'])
df.iloc[0, 1] = np.nan
df.iloc[2, 2] = np.nan
df.iloc[4, 0] = np.nan
print(df)
print("-------")
df.fillna(np.mean( df ) , inplace= True)
df
# Out:
#       A     B     C
# 0  80.0   NaN  43.0
# 1  33.0  31.0  23.0
# 2  38.0  73.0   NaN
# 3  67.0  30.0  80.0
# 4   NaN  53.0  51.0
# -------
#            A          B          C
# 0  80.000000  50.166667  43.000000
# 1  33.000000  31.000000  23.000000
# 2  38.000000  73.000000  50.166667
# 3  67.000000  30.000000  80.000000
# 4  50.166667  53.000000  51.000000

# %%
#Assignment 3.2
df = pd.DataFrame(np.random.randint(1, 100, size=(5, 3)), columns=['A', 'B', 'C'])
df.iloc[0, 1] = np.nan
df.iloc[2, 2] = np.nan
df.iloc[4, 0] = np.nan
print(df)
print("-------")
df.dropna(inplace=True)
df
# Out:
#       A     B     C
# 0  15.0   NaN  15.0
# 1  85.0   1.0  73.0
# 2  76.0  10.0   NaN
# 3  27.0   7.0  78.0
# 4   NaN  59.0  34.0
# -------
#       A    B     C
# 1  85.0  1.0  73.0
# 3  27.0  7.0  78.0

# %%
#Assignment 4.1
df = pd.DataFrame({'Category': np.random.choice(['A', 'B', 'C'], size=10), 'Value': np.random.randint(1, 21, size=10)})
print(df)
print("-------")
grouped = df.groupby('Category')['Value'].agg(['sum', 'mean'])
grouped
# Out:
#   Category  Value
# 0        A      1
# 1        A     18
# 2        B     11
# 3        B     18
# 4        A      3
# 5        A      7
# 6        C      1
# 7        A      5
# 8        B      7
# 9        B     13
# -------
#           sum   mean
# Category
# A          34   6.80
# B          49  12.25
# C           1   1.00

# %%
#Assignment 4.2
df = pd.DataFrame({"Product" : np.random.choice(['cake','beer','soda'] ,size = 10) , "Category" : np.random.choice(['A' , 'B' , 'C' ] , size= 10) , 'Value' : np.random.randint(1 , 100 , size=10)})
print(df)

df.groupby('Category')['Value'].agg(['sum'])
# Out:
#   Product Category  Value
# 0    soda        C     49
# 1    soda        A     94
# 2    soda        A     51
# 3    cake        C     83
# 4    cake        B     45
# 5    beer        B      5
# 6    soda        B     63
# 7    beer        A     44
# 8    soda        A     84
# 9    beer        C     21
#           sum
# Category
# A         273
# B         113
# C         153

# %%
#Assignment 5.1
df_1 = pd.DataFrame({'A' : ['a' , 'b' , 'c']  , 'Value1' : np.random.randint(1 , 11 , size=3) })
df_2 = pd.DataFrame({'A' : ['a' , 'b' , 'c']  , 'Value2' : np.random.randint(1 , 11 , size=3) })

print(df_1)
print(df_2)

new_df = pd.merge(df_1,df_2 , on='A')
new_df
# Out:
#    A  Value1
# 0  a       9
# 1  b      10
# 2  c       9
#    A  Value2
# 0  a       7
# 1  b       5
# 2  c       9
#    A  Value1  Value2
# 0  a       9       7
# 1  b      10       5
# 2  c       9       9

# %%
#Assignment 5.2
df_1 = pd.DataFrame(np.random.randint(1 , 11 , size = (6 ,4)) , columns= [ 'A' , 'B' , 'C' , 'D'])
df_2 = pd.DataFrame(np.random.randint(1 , 11 , size = (6 ,4)) , columns= [ 'F' , 'G' , 'H' , 'I'])


new_df_1 = pd.concat([df_1,df_2] ,axis=0)
print(new_df_1)
new_df = pd.concat([df_1,df_2] ,axis=1)
print("--d")
print(new_df)
# Out:
#       A     B     C     D    F    G    H    I
# 0  10.0  10.0  10.0   2.0  NaN  NaN  NaN  NaN
# 1  10.0   8.0   9.0   9.0  NaN  NaN  NaN  NaN
# 2   5.0   9.0   3.0   8.0  NaN  NaN  NaN  NaN
# 3   5.0  10.0   2.0   8.0  NaN  NaN  NaN  NaN
# 4   5.0  10.0   5.0  10.0  NaN  NaN  NaN  NaN
# 5   8.0  10.0   8.0   7.0  NaN  NaN  NaN  NaN
# 0   NaN   NaN   NaN   NaN  6.0  3.0  9.0  8.0
# 1   NaN   NaN   NaN   NaN  2.0  5.0  1.0  8.0
# 2   NaN   NaN   NaN   NaN  5.0  8.0  4.0  4.0
# 3   NaN   NaN   NaN   NaN  3.0  5.0  8.0  7.0
# 4   NaN   NaN   NaN   NaN  8.0  7.0  3.0  1.0
# 5   NaN   NaN   NaN   NaN  7.0  6.0  4.0  1.0
# --d
#     A   B   C   D  F  G  H  I
# 0  10  10  10   2  6  3  9  8
# 1  10   8   9   9  2  5  1  8
# 2   5   9   3   8  5  8  4  4
# 3   5  10   2   8  3  5  8  7
# 4   5  10   5  10  8  7  3  1
# 5   8  10   8   7  7  6  4  1

# %%
#Assignment 6.1
df = pd.DataFrame( {"Date" : pd.date_range(start='2024-01-01' , end= "2024-12-31") , 'Value' : np.random.randint( 1, 21 , size=366)})
df.set_index('Date' , inplace=True)

mean = df.resample('M').mean()
mean
# Out:
# C:\Users\koonc\AppData\Local\Temp\ipykernel_21744\2418020267.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   mean = df.resample('M').mean()
#                 Value
# Date
# 2024-01-31   9.129032
# 2024-02-29  10.275862
# 2024-03-31  10.806452
# 2024-04-30   8.733333
# 2024-05-31   9.612903
# 2024-06-30   8.400000
# 2024-07-31  11.387097
# 2024-08-31   9.419355
# 2024-09-30  10.900000
# 2024-10-31  12.516129
# 2024-11-30  11.166667
# 2024-12-31   9.032258

# %%
#Assignment 6.2
df = pd.DataFrame({'Date' : pd.date_range(start='2021-01-01' , end= '2021-12-31') , 'Value' : np.random.randint(1, 21 , size = 365)})
df.set_index('Date' , inplace=True)

mean_seven_day = df.rolling(window=7).mean()
mean_seven_day
# Out:
#                 Value
# Date
# 2021-01-01        NaN
# 2021-01-02        NaN
# 2021-01-03        NaN
# 2021-01-04        NaN
# 2021-01-05        NaN
# ...               ...
# 2021-12-27  11.571429
# 2021-12-28  11.285714
# 2021-12-29  11.285714
# 2021-12-30  11.714286
# 2021-12-31  12.714286
#
# [365 rows x 1 columns]

# %%
#Assignment 7.1

arrays = [['A', 'A', 'B', 'B'], ['one', 'two', 'one', 'two']]
index = pd.MultiIndex.from_arrays(arrays, names=('Category', 'SubCategory'))
df = pd.DataFrame(np.random.randint(1, 100, size=(4, 3)), index=index, columns=['Value1', 'Value2', 'Value3'])
print(df)

print(df.loc['A'])
print("-------")
print(df.loc[('B', 'two')])
# Out:
#                       Value1  Value2  Value3
# Category SubCategory
# A        one              23      77       2
#          two              41      19      99
# B        one              90      32      98
#          two               8      32      15
#              Value1  Value2  Value3
# SubCategory
# one              23      77       2
# two              41      19      99
# -------
# Value1     8
# Value2    32
# Value3    15
# Name: (B, two), dtype: int32

# %%
#Assignment 7.2
arr = [['A','A','B','B'] , ['1','2','1','2']]
index = pd.MultiIndex.from_arrays(arr, names=("Category" , 'SubCategory'))
df = pd.DataFrame( np.random.randint(1,21,size=(4, 1)) , index=index, columns=['value1'])
print(df)
sum_values = df.groupby(['Category', 'SubCategory']).sum()
sum_values
# Out:
#                       value1
# Category SubCategory
# A        1                 1
#          2                17
# B        1                13
#          2                13
#                       value1
# Category SubCategory
# A        1                 1
#          2                17
# B        1                13
#          2                13

# %%
#assignment 8.1
df = pd.DataFrame({
    'Date': pd.date_range(start='2024-01-01', end='2024-01-07'),
    'Category': np.random.choice(['A', 'B', 'C'], size=7),
    'Value': np.random.randint(1, 21, size=7)
})

print(df)

df.pivot_table(values="Value" , index= 'Date' , columns="Category")
# Out:
#         Date Category  Value
# 0 2024-01-01        C     15
# 1 2024-01-02        B      5
# 2 2024-01-03        A     15
# 3 2024-01-04        A     20
# 4 2024-01-05        C      8
# 5 2024-01-06        B     14
# 6 2024-01-07        C      2
# Category       A     B     C
# Date
# 2024-01-01   NaN   NaN  15.0
# 2024-01-02   NaN   5.0   NaN
# 2024-01-03  15.0   NaN   NaN
# 2024-01-04  20.0   NaN   NaN
# 2024-01-05   NaN   NaN   8.0
# 2024-01-06   NaN  14.0   NaN
# 2024-01-07   NaN   NaN   2.0

# %%
#Assignment 8.2 
df = pd.DataFrame({ 'Year' : np.random.choice(['2024' ,'2025' ,'2026' , '2027'] ,size = 10) ,
                   'Quater' : np.random.choice(['1','2','3'] , size = 10) , 
                   'Revanue' : np.random.randint(1000,5000 , size = 10)})

df.pivot_table(values='Revanue', index='Year', columns='Quater', aggfunc='mean')
# Out:
# Quater       1       2       3
# Year
# 2024       NaN     NaN  2284.5
# 2025    2183.5     NaN     NaN
# 2026    1227.0  4069.0  3725.0
# 2027    3693.0  3029.5     NaN

# %%
#Assignment 9.1
df = pd.DataFrame( np.random.randint(1,11,size = (3,4)) , index=['A','B','C'] , columns=['a','b','c','d'])
print(df)
df = df.applymap(lambda x : x*2)
df
# Out:
#    a  b  c   d
# A  7  6  4   5
# B  3  6  9  10
# C  5  2  5   2
# C:\Users\koonc\AppData\Local\Temp\ipykernel_21744\1670810050.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x : x*2)
#     a   b   c   d
# A  14  12   8  10
# B   6  12  18  20
# C  10   4  10   4

# %%
#Assignment 9.2
df = pd.DataFrame( np.random.randint(1,11,size = (6,4)) , index=['A','B','C','D','E','F'] , columns=['a','b','c','d'])
df['new'] = df.apply(lambda x : x.sum() , axis=1)
df
# Out:
#     a   b  c  d  new
# A  10   9  3  6   28
# B   2   3  9  3   17
# C   9  10  3  6   28
# D   3   4  4  6   17
# E   5  10  9  7   31
# F   8   4  4  4   20

# %%
#Assignment 10.1
s = pd.Series(['Car','Can','Bird','Human'])
s = s.str.upper()
s
# Out:
# 0      CAR
# 1      CAN
# 2     BIRD
# 3    HUMAN
# dtype: object

# %%
#Assignment 10.2
s = pd.Series(['Car','Can','Bird','Human'])
s.str[:3]
# Out:
# 0    Car
# 1    Can
# 2    Bir
# 3    Hum
# dtype: object

# %%
#practice

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

dates = pd.date_range(start='2023-01-01', periods=100, freq='D')

categories = ['A', 'B', 'C']

df = pd.DataFrame({
    'Date': dates,
    'Category': np.random.choice(categories, size=100),
    'Value': np.random.randint(10, 100, size=100),          
    'Score': np.random.normal(loc=50, scale=10, size=100)     
})

print(df.head())
# Out:
#         Date Category  Value      Score
# 0 2023-01-01        C     17  50.602302
# 1 2023-01-02        A     97  74.632421
# 2 2023-01-03        C     72  48.076390
# 3 2023-01-04        C     20  53.015473
# 4 2023-01-05        A     90  49.652882

# %%
plt.hist(df['Score'] , bins= 30)
plt.xlabel('Score')
plt.ylabel('Density')
plt.show()
